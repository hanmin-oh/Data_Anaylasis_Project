# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import missingno as msno
plt.rc('font', family='D2Coding')
from plotnine import *
import folium
from folium.plugins import MiniMap
from geopy.geocoders import Nominatim
import requests

# %%
middle_study = pd.read_csv('./data/중학교 방과후.csv')
middle_study
# Out:
#                 학교명 설립구분  교과프로그램수  교과수강학생수  특기적성프로그램수  특기적성수강학생수  프로그램수(계)  \
# 0             개원중학교   공립        4       29          5         75         9
# 1             경원중학교   공립        0        0          9        159         9
# 2             구룡중학교   공립        3       33          2         51         5
# 3            압구정중학교   공립        0        0          6         77         6
# 4    단국대학교사범대학부속중학교   사립        0        0          5         81         5
# ..              ...  ...      ...      ...        ...        ...       ...
# 382           항동중학교   공립        4       39          8        130        12
# 383           신길중학교   공립        1       18          6         76         7
# 384         마곡하늬중학교   공립        3       43          7         90        10
# 385          해누리중학교   공립        2       28          7        304         9
# 386           강빛중학교   공립        7       41          3         27        10
#
#      수강학생수(계)  방과후학교참여학생수  방과후학교 수익자부담금액  방과후학교 수익자부담외지원금액
# 0         104         104        5553450            333900
# 1         159         157        6135500           3885000
# 2          84          84       15336310           1352620
# 3          77          77              0          12000000
# 4          81          81        2964340           5287330
# ..        ...         ...            ...               ...
# 382       169         121        1946000          13296000
# 383        94          84        1440000             60000
# 384       133         105       13280000          25227000
# 385       332         332        3350000           2275000
# 386        68          68              0          25800000
#
# [387 rows x 11 columns]

# %%
high_study = pd.read_csv('./data/고등학교 방과후.csv')
high_study
# Out:
#                  학교명 설립구분  교과프로그램수  교과수강학생수  특기적성프로그램수  특기적성수강학생수  프로그램수(계)  \
# 0             가락고등학교   공립        0        0          0          0         0
# 1             강동고등학교   사립        4       97          0          0         4
# 2             강서고등학교   사립        4       33          2         17         6
# 3             개포고등학교   공립        0        0          0          0         0
# 4    건국대학교사범대학부속고등학교   사립       57      137          0          0        57
# ..               ...  ...      ...      ...        ...        ...       ...
# 313          가재울고등학교   공립        0        0          1         15         1
# 314           하나고등학교   사립        0        0          0          0         0
# 315           금호고등학교   공립        0        0          0          0         0
# 316           도선고등학교   공립        2       20          0          0         2
# 317      덕수고등학교(일반고)   공립        5       61          0          0         5
#
#      수강학생수(계)  방과후학교참여학생수  방과후학교 수익자부담금액  방과후학교 수익자부담외지원금액
# 0           0           0        1665500           1034500
# 1          97          97       67573970           8687140
# 2          50          50       24932000           2253900
# 3           0           0              0                 0
# 4         137         129       18773600            857300
# ..        ...         ...            ...               ...
# 313        15          15        2637760           1487170
# 314         0           0      249465410          32426670
# 315         0           0        2340000           3960000
# 316        20          20        6547010          17027820
# 317        61          61        3549000             56000
#
# [318 rows x 11 columns]

# %%
high_student = pd.read_csv('./data/고등학교 학생수.csv')
high_student
# Out:
#                     학교명  1학년(남)  1학년(여)  2학년(남)  2학년(여)  3학년(남)  3학년(여)  계(남)  \
# 0                가락고등학교      90     147      97     154     125     154   312
# 1                강동고등학교     141      76     107      88     110      93   358
# 2                강서고등학교     328       0     331       0     333       0   992
# 3                개포고등학교      94     123      98     106      99     114   296
# 4       건국대학교사범대학부속고등학교     193     130     192     122     194     135   579
# ..                  ...     ...     ...     ...     ...     ...     ...   ...
# 318    경동고등학교부설방송통신고등학교      27      48      26      62      40      64    93
# 319    경복고등학교부설방송통신고등학교      26      99      30      74      47      92   103
# 320  수도여자고등학교부설방송통신고등학교       0      73       0      93       0      69     0
# 321   영등포고등학교부설방송통신고등학교      25      36      28      46      29      45    82
# 322  경기여자고등학교부설방송통신고등학교       0     103       0     110       0     123     0
#
#      계(여)   총계
# 0     455  767
# 1     257  615
# 2       0  992
# 3     343  639
# 4     387  966
# ..    ...  ...
# 318   174  267
# 319   265  368
# 320   235  235
# 321   127  209
# 322   336  336
#
# [323 rows x 10 columns]

# %%
high_info = pd.read_csv('./data/고등학교 정보.csv')
high_info
# Out:
#         시도교육청     지역교육청          지역   정보공시 학교코드              학교명  학교급코드 설립구분  \
# 0    서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010000370           가락고등학교      4   공립
# 1    서울특별시교육청  서울특별시교육청   서울특별시 강동구  S010000371           강동고등학교      4   사립
# 2    서울특별시교육청  서울특별시교육청   서울특별시 양천구  S010000372           강서고등학교      4   사립
# 3    서울특별시교육청  서울특별시교육청   서울특별시 강남구  S010000373           개포고등학교      4   공립
# 4    서울특별시교육청  서울특별시교육청   서울특별시 광진구  S010000374  건국대학교사범대학부속고등학교      4   사립
# ..        ...       ...         ...         ...              ...    ...  ...
# 313  서울특별시교육청  서울특별시교육청  서울특별시 서대문구  S010005591          가재울고등학교      4   공립
# 314  서울특별시교육청  서울특별시교육청   서울특별시 은평구  S010005616           하나고등학교      4   사립
# 315  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006381           금호고등학교      4   공립
# 316  서울특별시교육청  서울특별시교육청   서울특별시 성동구  S010006382           도선고등학교      4   공립
# 317  서울특별시교육청  서울특별시교육청   서울특별시 송파구  S010006558      덕수고등학교(일반고)      4   공립
#
#        학교특성 분교여부 설립유형  ...      우편번호  학교도로명 우편번호               학교도로명 주소  \
# 0    일반고등학교    N   단설  ...  138170.0        5678       서울특별시 송파구 송이로 42
# 1    일반고등학교    N   단설  ...  134837.0        5279     서울특별시 강동구 구천면로 572
# 2    일반고등학교    N   단설  ...  158814.0        7958    서울특별시 양천구 목동중앙남로 27
# 3    일반고등학교    N   단설  ...  135240.0        6324      서울특별시 강남구 개포로 402
# 4    일반고등학교    N   부속  ...  143701.0        5029      서울특별시 광진구 능동로 120
# ..      ...  ...  ...  ...       ...         ...                    ...
# 313  일반고등학교    N   단설  ...  120811.0        3709  서울특별시 서대문구 수색로 100-35
# 314  자율고등학교    N   단설  ...  122200.0        3305      서울특별시 은평구 연서로 535
# 315  일반고등학교    N   단설  ...       NaN        4727      서울특별시 성동구 금호로 118
# 316  일반고등학교    N   단설  ...       NaN        4701      서울특별시 성동구 마장로 156
# 317  일반고등학교    N   단설  ...       NaN        5846      서울특별시 송파구 위례북로 10
#
#                   학교도로명 상세주소         위도          경도           전화번호  \
# 0               (송파동,가락고등학교)  37.501637  127.116943    02-416-4658
# 1                      (상일동)  37.549890  127.160702    02-427-0231
# 2              , 강서고등학교 (목동)  37.536777  126.866330   02-2642-0725
# 3              (개포동, 개포고등학교)  37.484959  127.059405    02-576-3333
# 4    , 건국대학교사범대학부속고등학교 (화양동)  37.540060  127.080340  070-7012-3500
# ..                       ...        ...         ...            ...
# 313                   (북가좌동)  37.574297  126.909499   02-6351-0500
# 314           , 하나고등학교 (진관동)  37.641637  126.936930   02-6913-1111
# 315                  (금호동1가)  37.553250  127.023620   02-2022-0800
# 316                  (하왕십리동)  37.567131  127.026809   02-2292-8175
# 317            (거여동, 덕수고등학교)  37.485367  127.146854   02-6952-2801
#
#              팩스번호                     홈페이지 주소 남녀공학 구분
# 0     02-421-9669      http://garak.sen.hs.kr    남녀공학
# 1     02-441-3494   http://kangdong.sen.hs.kr    남녀공학
# 2    02-2651-3046    http://gangseo.sen.hs.kr       남
# 3     02-571-6560      http://gaepo.sen.hs.kr    남녀공학
# 4     02-456-0646     http://konkuk.sen.hs.kr    남녀공학
# ..            ...                         ...     ...
# 313   02-307-6605    http://gajaeul.sen.hs.kr    남녀공학
# 314  02-6913-1785       http://www.hana.hs.kr    남녀공학
# 315  02-2022-0840     http://geumho.sen.hs.kr    남녀공학
# 316  02-2292-7556      http://dosun.sen.hs.kr    남녀공학
# 317   02-449-9069  https://duksoowr.sen.hs.kr    남녀공학
#
# [318 rows x 26 columns]

# %%
high_info.columns
# Out:
# Index(['시도교육청', '지역교육청', '지역', '정보공시 학교코드', '학교명', '학교급코드', '설립구분', '학교특성',
#        '분교여부', '설립유형', '주야구분', '개교기념일', '설립일', '법정동코드', '주소내역', '상세주소내역',
#        '우편번호', '학교도로명 우편번호', '학교도로명 주소', '학교도로명 상세주소', '위도', '경도', '전화번호',
#        '팩스번호', '홈페이지 주소', '남녀공학 구분'],
#       dtype='object')

# %%
high_info.drop(columns=['시도교육청', '지역교육청','학교급코드', '지역', '정보공시 학교코드','설립구분', '학교특성',
       '분교여부', '설립유형', '주야구분', '개교기념일', '설립일', '법정동코드', '주소내역', '상세주소내역', '우편번호', '학교도로명 우편번호',
        '전화번호', '팩스번호', '홈페이지 주소', '남녀공학 구분'], inplace=True)
high_info
# Out:
#                  학교명               학교도로명 주소               학교도로명 상세주소  \
# 0             가락고등학교       서울특별시 송파구 송이로 42             (송파동,가락고등학교)
# 1             강동고등학교     서울특별시 강동구 구천면로 572                    (상일동)
# 2             강서고등학교    서울특별시 양천구 목동중앙남로 27            , 강서고등학교 (목동)
# 3             개포고등학교      서울특별시 강남구 개포로 402            (개포동, 개포고등학교)
# 4    건국대학교사범대학부속고등학교      서울특별시 광진구 능동로 120  , 건국대학교사범대학부속고등학교 (화양동)
# ..               ...                    ...                      ...
# 313          가재울고등학교  서울특별시 서대문구 수색로 100-35                   (북가좌동)
# 314           하나고등학교      서울특별시 은평구 연서로 535           , 하나고등학교 (진관동)
# 315           금호고등학교      서울특별시 성동구 금호로 118                  (금호동1가)
# 316           도선고등학교      서울특별시 성동구 마장로 156                  (하왕십리동)
# 317      덕수고등학교(일반고)      서울특별시 송파구 위례북로 10            (거여동, 덕수고등학교)
#
#             위도          경도
# 0    37.501637  127.116943
# 1    37.549890  127.160702
# 2    37.536777  126.866330
# 3    37.484959  127.059405
# 4    37.540060  127.080340
# ..         ...         ...
# 313  37.574297  126.909499
# 314  37.641637  126.936930
# 315  37.553250  127.023620
# 316  37.567131  127.026809
# 317  37.485367  127.146854
#
# [318 rows x 5 columns]

# %%
# 네이버 개발자 포털에서 발급한 Client ID와 Client Secret
client_id = '5j924usqjd'
client_secret = 'W4wjDI2jRzuvP1N0zo9UiG1zTRoDP30idjpESbp4'

# '위도'와 '경도' 정보가 있는 데이터프레임 (house_df)에서 반복적으로 역 지오코딩을 수행합니다.
for index, row in high_info.iterrows():
    latitude = row['위도']
    longitude = row['경도']
#     https://naveropenapi.apigw.ntruss.com/map-reversegeocode/v2/gc?request=coordsToaddr&coords=129.1133567,35.2982640&sourcecrs=epsg:4326&output=json&orders=addr,admcode
    if latitude is not None and longitude is not None:
        url = f'https://naveropenapi.apigw.ntruss.com/map-reversegeocode/v2/gc?request=coordsToaddr&coords={longitude},{latitude}&sourcecrs=epsg:4326&output=json&orders=addr,admcode'
        headers = {
            'X-NCP-APIGW-API-KEY-ID': client_id,
            'X-NCP-APIGW-API-KEY': client_secret
        }
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            data = response.json()
            if data.get('results'):
                gu = data['results'][0]['region']['area2']['name']  # 예시로 주소 중 'area3'의 'name' 사용
                dong = data['results'][0]['region']['area3']['name']  # 예시로 주소 중 'area3'의 'name' 사용
                high_info.at[index, '법정동'] = dong  # 주소 정보를 데이터프레임에 추가
                high_info.at[index, '시군구'] = gu  # 주소 정보를 데이터프레임에 추가
                
high_info
# Out:
#                  학교명               학교도로명 주소               학교도로명 상세주소  \
# 0             가락고등학교       서울특별시 송파구 송이로 42             (송파동,가락고등학교)
# 1             강동고등학교     서울특별시 강동구 구천면로 572                    (상일동)
# 2             강서고등학교    서울특별시 양천구 목동중앙남로 27            , 강서고등학교 (목동)
# 3             개포고등학교      서울특별시 강남구 개포로 402            (개포동, 개포고등학교)
# 4    건국대학교사범대학부속고등학교      서울특별시 광진구 능동로 120  , 건국대학교사범대학부속고등학교 (화양동)
# ..               ...                    ...                      ...
# 313          가재울고등학교  서울특별시 서대문구 수색로 100-35                   (북가좌동)
# 314           하나고등학교      서울특별시 은평구 연서로 535           , 하나고등학교 (진관동)
# 315           금호고등학교      서울특별시 성동구 금호로 118                  (금호동1가)
# 316           도선고등학교      서울특별시 성동구 마장로 156                  (하왕십리동)
# 317      덕수고등학교(일반고)      서울특별시 송파구 위례북로 10            (거여동, 덕수고등학교)
#
#             위도          경도    법정동   시군구
# 0    37.501637  127.116943    송파동   송파구
# 1    37.549890  127.160702    상일동   강동구
# 2    37.536777  126.866330     목동   양천구
# 3    37.484959  127.059405    개포동   강남구
# 4    37.540060  127.080340    화양동   광진구
# ..         ...         ...    ...   ...
# 313  37.574297  126.909499   북가좌동  서대문구
# 314  37.641637  126.936930    진관동   은평구
# 315  37.553250  127.023620  금호동1가   성동구
# 316  37.567131  127.026809  하왕십리동   성동구
# 317  37.485367  127.146854    거여동   송파구
#
# [318 rows x 7 columns]

# %%
high_info.drop(columns=['학교도로명 주소', '학교도로명 상세주소', '위도', '경도'], inplace=True)
high_info
# Out:
#                  학교명    법정동   시군구
# 0             가락고등학교    송파동   송파구
# 1             강동고등학교    상일동   강동구
# 2             강서고등학교     목동   양천구
# 3             개포고등학교    개포동   강남구
# 4    건국대학교사범대학부속고등학교    화양동   광진구
# ..               ...    ...   ...
# 313          가재울고등학교   북가좌동  서대문구
# 314           하나고등학교    진관동   은평구
# 315           금호고등학교  금호동1가   성동구
# 316           도선고등학교  하왕십리동   성동구
# 317      덕수고등학교(일반고)    거여동   송파구
#
# [318 rows x 3 columns]

# %%
grouped = high_info.groupby(['시군구', '법정동']).size().reset_index(name='학교수')
grouped
# Out:
#      시군구  법정동  학교수
# 0    강남구  개포동    3
# 1    강남구  대치동    3
# 2    강남구  도곡동    3
# 3    강남구  삼성동    1
# 4    강남구  수서동    2
# ..   ...  ...  ...
# 145  중랑구  망우동    5
# 146  중랑구  면목동    1
# 147  중랑구   묵동    2
# 148  중랑구  상봉동    1
# 149  중랑구  중화동    1
#
# [150 rows x 3 columns]

# %%
# '강북구, '도봉구', '노원구' , '중랑구', '동대문구' 선택
selected_districts = ['강북구', '도봉구', '노원구', '성북구', '중랑구', '동대문구']
filtered_df = grouped[grouped['시군구'].isin(selected_districts)]
filtered_df
# Out:
#       시군구    법정동  학교수
# 17    강북구    미아동    6
# 18    강북구    수유동    1
# 41    노원구    공릉동    2
# 42    노원구    상계동    6
# 43    노원구    월계동    5
# 44    노원구    중계동    9
# 45    노원구    하계동    3
# 46    도봉구    도봉동    2
# 47    도봉구    방학동    1
# 48    도봉구    쌍문동    4
# 49    도봉구     창동    3
# 50   동대문구    신설동    1
# 51   동대문구    이문동    1
# 52   동대문구    장안동    1
# 53   동대문구    전농동    2
# 54   동대문구    제기동    1
# 55   동대문구   청량리동    1
# 56   동대문구    회기동    1
# 57   동대문구    휘경동    3
# 86    성북구    길음동    1
# 87    성북구    돈암동    1
# 88    성북구  동선동4가    1
# 89    성북구  삼선동2가    1
# 90    성북구  삼선동3가    1
# 91    성북구    석관동    1
# 92    성북구    성북동    2
# 93    성북구  안암동2가    1
# 94    성북구    정릉동    3
# 95    성북구   하월곡동    1
# 145   중랑구    망우동    5
# 146   중랑구    면목동    1
# 147   중랑구     묵동    2
# 148   중랑구    상봉동    1
# 149   중랑구    중화동    1

# %%
width = pd.read_csv('./data/동북부면적.csv')
width = width.drop(columns=['Unnamed: 0'], axis=1)
width
# Out:
#      시군구    법정동       면적
# 0    강북구    미아동   4370.0
# 1    강북구     번동   2710.0
# 2    강북구    수유동   6240.0
# 3    강북구    우이동  10280.0
# 4    노원구    공릉동   8230.0
# 5    노원구    상계동  15680.0
# 6    노원구    월계동   4270.0
# 7    노원구    중계동   5200.0
# 8    노원구    하계동   2060.0
# 9    도봉구    도봉동   9550.0
# 10   도봉구    방학동   4050.0
# 11   도봉구    쌍문동   2800.0
# 12   도봉구     창동   4250.0
# 13  동대문구   답십리동   1660.0
# 14  동대문구    용두동   1610.0
# 15  동대문구    이문동   1730.0
# 16  동대문구    장안동   2340.0
# 17  동대문구    전농동   2050.0
# 18  동대문구    제기동   1180.0
# 19  동대문구   청량리동   1200.0
# 20  동대문구    회기동    760.0
# 21  동대문구    휘경동   1680.0
# 22   성북구    길음동   1370.0
# 23   성북구    돈암동    970.0
# 24   성북구  동선동3가    730.0
# 25   성북구  보문동7가    560.0
# 26   성북구  삼선동4가    920.0
# 27   성북구   상월곡동   1360.0
# 28   성북구    석관동   1730.0
# 29   성북구    성북동   2860.0
# 30   성북구  안암동2가   1330.0
# 31   성북구    장위동   2020.0
# 32   성북구    정릉동   8450.0
# 33   성북구    종암동   1460.0
# 34   성북구   하월곡동    810.0
# 35   중랑구    망우동   3950.0
# 36   중랑구    면목동   6010.0
# 37   중랑구     묵동   1870.0
# 38   중랑구    상봉동   1530.0
# 39   중랑구    신내동   3490.0
# 40   중랑구    중화동   1650.0

# %%
width['면적'] = width['면적'] * 0.001
width
# Out:
#      시군구    법정동     면적
# 0    강북구    미아동   4.37
# 1    강북구     번동   2.71
# 2    강북구    수유동   6.24
# 3    강북구    우이동  10.28
# 4    노원구    공릉동   8.23
# 5    노원구    상계동  15.68
# 6    노원구    월계동   4.27
# 7    노원구    중계동   5.20
# 8    노원구    하계동   2.06
# 9    도봉구    도봉동   9.55
# 10   도봉구    방학동   4.05
# 11   도봉구    쌍문동   2.80
# 12   도봉구     창동   4.25
# 13  동대문구   답십리동   1.66
# 14  동대문구    용두동   1.61
# 15  동대문구    이문동   1.73
# 16  동대문구    장안동   2.34
# 17  동대문구    전농동   2.05
# 18  동대문구    제기동   1.18
# 19  동대문구   청량리동   1.20
# 20  동대문구    회기동   0.76
# 21  동대문구    휘경동   1.68
# 22   성북구    길음동   1.37
# 23   성북구    돈암동   0.97
# 24   성북구  동선동3가   0.73
# 25   성북구  보문동7가   0.56
# 26   성북구  삼선동4가   0.92
# 27   성북구   상월곡동   1.36
# 28   성북구    석관동   1.73
# 29   성북구    성북동   2.86
# 30   성북구  안암동2가   1.33
# 31   성북구    장위동   2.02
# 32   성북구    정릉동   8.45
# 33   성북구    종암동   1.46
# 34   성북구   하월곡동   0.81
# 35   중랑구    망우동   3.95
# 36   중랑구    면목동   6.01
# 37   중랑구     묵동   1.87
# 38   중랑구    상봉동   1.53
# 39   중랑구    신내동   3.49
# 40   중랑구    중화동   1.65

# %%
merged_df = pd.merge(filtered_df, width, on=['시군구', '법정동'], how='inner')
merged_df
# Out:
#      시군구    법정동  학교수     면적
# 0    강북구    미아동    6   4.37
# 1    강북구    수유동    1   6.24
# 2    노원구    공릉동    2   8.23
# 3    노원구    상계동    6  15.68
# 4    노원구    월계동    5   4.27
# 5    노원구    중계동    9   5.20
# 6    노원구    하계동    3   2.06
# 7    도봉구    도봉동    2   9.55
# 8    도봉구    방학동    1   4.05
# 9    도봉구    쌍문동    4   2.80
# 10   도봉구     창동    3   4.25
# 11  동대문구    이문동    1   1.73
# 12  동대문구    장안동    1   2.34
# 13  동대문구    전농동    2   2.05
# 14  동대문구    제기동    1   1.18
# 15  동대문구   청량리동    1   1.20
# 16  동대문구    회기동    1   0.76
# 17  동대문구    휘경동    3   1.68
# 18   성북구    길음동    1   1.37
# 19   성북구    돈암동    1   0.97
# 20   성북구    석관동    1   1.73
# 21   성북구    성북동    2   2.86
# 22   성북구  안암동2가    1   1.33
# 23   성북구    정릉동    3   8.45
# 24   성북구   하월곡동    1   0.81
# 25   중랑구    망우동    5   3.95
# 26   중랑구    면목동    1   6.01
# 27   중랑구     묵동    2   1.87
# 28   중랑구    상봉동    1   1.53
# 29   중랑구    중화동    1   1.65

# %%
merged_df['면적(㎢)당 학교 수'] = merged_df['학교수']  / merged_df['면적']
merged_df
# Out:
#      시군구    법정동  학교수     면적  면적(㎢)당 학교 수
# 0    강북구    미아동    6   4.37     1.372998
# 1    강북구    수유동    1   6.24     0.160256
# 2    노원구    공릉동    2   8.23     0.243013
# 3    노원구    상계동    6  15.68     0.382653
# 4    노원구    월계동    5   4.27     1.170960
# 5    노원구    중계동    9   5.20     1.730769
# 6    노원구    하계동    3   2.06     1.456311
# 7    도봉구    도봉동    2   9.55     0.209424
# 8    도봉구    방학동    1   4.05     0.246914
# 9    도봉구    쌍문동    4   2.80     1.428571
# 10   도봉구     창동    3   4.25     0.705882
# 11  동대문구    이문동    1   1.73     0.578035
# 12  동대문구    장안동    1   2.34     0.427350
# 13  동대문구    전농동    2   2.05     0.975610
# 14  동대문구    제기동    1   1.18     0.847458
# 15  동대문구   청량리동    1   1.20     0.833333
# 16  동대문구    회기동    1   0.76     1.315789
# 17  동대문구    휘경동    3   1.68     1.785714
# 18   성북구    길음동    1   1.37     0.729927
# 19   성북구    돈암동    1   0.97     1.030928
# 20   성북구    석관동    1   1.73     0.578035
# 21   성북구    성북동    2   2.86     0.699301
# 22   성북구  안암동2가    1   1.33     0.751880
# 23   성북구    정릉동    3   8.45     0.355030
# 24   성북구   하월곡동    1   0.81     1.234568
# 25   중랑구    망우동    5   3.95     1.265823
# 26   중랑구    면목동    1   6.01     0.166389
# 27   중랑구     묵동    2   1.87     1.069519
# 28   중랑구    상봉동    1   1.53     0.653595
# 29   중랑구    중화동    1   1.65     0.606061

# %%
merged_df.drop(columns=['학교수', '면적'], inplace=True)
merged_df
# Out:
#      시군구    법정동  면적(㎢)당 학교 수
# 0    강북구    미아동     1.372998
# 1    강북구    수유동     0.160256
# 2    노원구    공릉동     0.243013
# 3    노원구    상계동     0.382653
# 4    노원구    월계동     1.170960
# 5    노원구    중계동     1.730769
# 6    노원구    하계동     1.456311
# 7    도봉구    도봉동     0.209424
# 8    도봉구    방학동     0.246914
# 9    도봉구    쌍문동     1.428571
# 10   도봉구     창동     0.705882
# 11  동대문구    이문동     0.578035
# 12  동대문구    장안동     0.427350
# 13  동대문구    전농동     0.975610
# 14  동대문구    제기동     0.847458
# 15  동대문구   청량리동     0.833333
# 16  동대문구    회기동     1.315789
# 17  동대문구    휘경동     1.785714
# 18   성북구    길음동     0.729927
# 19   성북구    돈암동     1.030928
# 20   성북구    석관동     0.578035
# 21   성북구    성북동     0.699301
# 22   성북구  안암동2가     0.751880
# 23   성북구    정릉동     0.355030
# 24   성북구   하월곡동     1.234568
# 25   중랑구    망우동     1.265823
# 26   중랑구    면목동     0.166389
# 27   중랑구     묵동     1.069519
# 28   중랑구    상봉동     0.653595
# 29   중랑구    중화동     0.606061

# %%
merged_df.to_csv('./data/동북부학교수.csv')

# %%
merge_df = pd.merge(high_study, high_student, on='학교명', how='inner')
merge_df
# Out:
#                  학교명 설립구분  교과프로그램수  교과수강학생수  특기적성프로그램수  특기적성수강학생수  프로그램수(계)  \
# 0             가락고등학교   공립        0        0          0          0         0
# 1             강동고등학교   사립        4       97          0          0         4
# 2             강서고등학교   사립        4       33          2         17         6
# 3             개포고등학교   공립        0        0          0          0         0
# 4    건국대학교사범대학부속고등학교   사립       57      137          0          0        57
# ..               ...  ...      ...      ...        ...        ...       ...
# 312          가재울고등학교   공립        0        0          1         15         1
# 313           하나고등학교   사립        0        0          0          0         0
# 314           금호고등학교   공립        0        0          0          0         0
# 315           도선고등학교   공립        2       20          0          0         2
# 316      덕수고등학교(일반고)   공립        5       61          0          0         5
#
#      수강학생수(계)  방과후학교참여학생수  방과후학교 수익자부담금액  방과후학교 수익자부담외지원금액  1학년(남)  1학년(여)  \
# 0           0           0        1665500           1034500      90     147
# 1          97          97       67573970           8687140     141      76
# 2          50          50       24932000           2253900     328       0
# 3           0           0              0                 0      94     123
# 4         137         129       18773600            857300     193     130
# ..        ...         ...            ...               ...     ...     ...
# 312        15          15        2637760           1487170      94     112
# 313         0           0      249465410          32426670     101     107
# 314         0           0        2340000           3960000      60      92
# 315        20          20        6547010          17027820      71      99
# 316        61          61        3549000             56000     158     136
#
#      2학년(남)  2학년(여)  3학년(남)  3학년(여)  계(남)  계(여)   총계
# 0        97     154     125     154   312   455  767
# 1       107      88     110      93   358   257  615
# 2       331       0     333       0   992     0  992
# 3        98     106      99     114   296   343  639
# 4       192     122     194     135   579   387  966
# ..      ...     ...     ...     ...   ...   ...  ...
# 312      92     102     108     110   307   328  635
# 313     100     103      97      99   298   309  607
# 314      52      80      64      83   186   259  445
# 315      60      78      66      83   206   270  476
# 316       0       0       0       0   160   137  297
#
# [317 rows x 20 columns]

# %%
merge_df.columns
# Out:
# Index(['학교명', '설립구분', '교과프로그램수', '교과수강학생수', '특기적성프로그램수', '특기적성수강학생수',
#        '프로그램수(계)', '수강학생수(계)', '방과후학교참여학생수', '방과후학교 수익자부담금액',
#        '방과후학교 수익자부담외지원금액', '1학년(남)', '1학년(여)', '2학년(남)', '2학년(여)', '3학년(남)',
#        '3학년(여)', '계(남)', '계(여)', '총계'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4100\539538562.py in <module>
# ----> 1 result.drop(co)
#
# NameError: name 'co' is not defined
